# %%
from google.colab import drive
drive.mount('/content/drive')

# !git config --global user.email "sarah06mohapatra@gmail.com"
# !git config --global user.name "SarahMohapatra"
# Move to the folder
# %cd /content/drive/MyDrive/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
# %pwd
# Out:
# '/content/drive/MyDrive'

# %%
# %cd GithubProjects/
# Out:
# /content/drive/MyDrive/GithubProjects

# %%
# !git clone https://github.com/SarahMohapatra/Basic-python-projects.git
# Out:
# Cloning into 'Basic-python-projects'...
# remote: Enumerating objects: 6, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6 (delta 1), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (6/6), done.
# Resolving deltas: 100% (1/1), done.

# %%
# %cd Basic-python-projects/
# Out:
# /content/drive/MyDrive/GithubProjects/Basic-python-projects

# %%
import getpass
token = getpass.getpass('Paste Token: ')

username = "SarahMohapatra"
repo = "Basic-python-projects"

# Link to GitHub using the token
# !git remote add origin https://{token}@github.com/{username}/{repo}.git

# !git add
# !git push -u origin main
